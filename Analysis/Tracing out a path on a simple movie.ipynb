# %%
import osos.chdir("/Users/Alex/Dropbox/Science/Datta lab/Presentations/Gordon (Bob)")

# %%
os.system("mkdir tmp_imgs")os.system("ffmpeg -i SimpleAssay.m4v tmp_imgs/%06d.png")
# Out:
# 0

# %%
import SimpleCV as scvd = scv.ImageSet("tmp_imgs/")

# %%
matshow(d[0].toGray().invert().getNumpy()[:,:,0])
# Out:
# &lt;matplotlib.image.AxesImage at 0x127130950&gt;

# %%
img.findBlobs?

# %%
b.x

# %%
q.lines?

# %%
centroids = []for i in range(len(d)):    img = d[i].toGray().invert()    img = img.crop(80,50,500,310)    blobs = img.findBlobs(threshval=100, minsize=1000, maxsize=7000)    if blobs:        b = blobs[-1]        centroids.append((b.x, b.y))        b.draw()                if len(centroids) > 2:            dl = img.getDrawingLayer()            dl.lines(centroids, width=3, color=(255,0,0))        img.show()
